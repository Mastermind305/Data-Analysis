# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df=pd.read_excel(r"C:\Users\hp\AssignmentComplete.xlsx")

# %%
print(df.head(5))
print(df.columns)
df.shape
# Out:
#                        Name  Rank  Year  Rating
# 0  The Shawshank Redemption     1  1994     9.2
# 1             The Godfather     2  1972     9.2
# 2           The Dark Knight     3  2008     9.0
# 3     The Godfather Part II     4  1974     9.0
# 4              12 Angry Men     5  1957     9.0
# Index(['Name', 'Rank', 'Year', 'Rating'], dtype='object')
# (250, 4)

# %%
df.describe()
# Out:
#              Rank         Year      Rating
# count  250.000000   250.000000  250.000000
# mean   125.500000  1986.360000    8.250800
# std     72.312977    25.125356    0.235971
# min      1.000000  1921.000000    8.000000
# 25%     63.250000  1966.250000    8.100000
# 50%    125.500000  1994.000000    8.200000
# 75%    187.750000  2006.000000    8.400000
# max    250.000000  2022.000000    9.200000

# %%
df.isna().sum()
# Out:
# Name      0
# Rank      0
# Year      0
# Rating    0
# dtype: int64

# %%
df=df.loc[~df.duplicated(subset=['Name','Rank','Year','Rating'])].reset_index(drop=True)
# Out:
#                          Name  Rank  Year  Rating
# 0    The Shawshank Redemption     1  1994     9.2
# 1               The Godfather     2  1972     9.2
# 2             The Dark Knight     3  2008     9.0
# 3       The Godfather Part II     4  1974     9.0
# 4                12 Angry Men     5  1957     9.0
# ..                        ...   ...   ...     ...
# 245               Dersu Uzala   246  1975     8.0
# 246                  The Help   247  2011     8.0
# 247                   Aladdin   248  1992     8.0
# 248                    Gandhi   249  1982     8.0
# 249        Dances with Wolves   250  1990     8.0
#
# [250 rows x 4 columns]

# %%
df["Year"].value_counts()
# Out:
# 1995    8
# 2004    7
# 2009    6
# 1957    6
# 2003    6
#        ..
# 2022    1
# 1941    1
# 1958    1
# 1987    1
# 1934    1
# Name: Year, Length: 86, dtype: int64

# %%
ax=df["Year"].value_counts().head(10).plot(kind='bar',title="Top Years")
ax.set_xlabel("Years")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df["Rating"].plot(kind='hist',bins=15, title='No. of movies per ratings')
# Out:
# <AxesSubplot: title={'center': 'No. of movies per ratings'}, ylabel='Frequency'>

# %%
ax=df["Rating"].plot(kind='kde',title='Rating count')
ax.set_xlabel('Ratings')
# Out:
# Text(0.5, 0, 'Ratings')

# %%
df.plot(kind='scatter',x="Year",y="Rank",title='Relationship between Year and Rating')
plt.show()

# %%
sns.scatterplot(df, x="Rank",y="Rating")
# Out:
# <AxesSubplot: xlabel='Rank', ylabel='Rating'>

# %%
sns.pairplot(df,vars=["Year","Rating","Rank"])

# %%
a=df[["Year","Rating","Rank"]].dropna().corr()
a
# Out:
#             Year    Rating      Rank
# Year    1.000000  0.048045 -0.055716
# Rating  0.048045  1.000000 -0.901169
# Rank   -0.055716 -0.901169  1.000000

# %%
sns.heatmap(a, annot=True)
# Out:
# <AxesSubplot: >
